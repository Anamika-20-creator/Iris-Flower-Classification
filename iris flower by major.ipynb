# %%
import pandas as pd
import numpy as np 
import warnings 
warnings.filterwarnings ('ignore')

# %%
# importing dataset
Iris_df = pd.read_csv(r'C:\Users\USER\Desktop\Iris.csv')

# %%
# To see the dataframe
Iris_df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Iris_df.shape
# Out:
# (150, 6)

# %%
Iris_df.columns.values.tolist()
# Out:
# ['Id',
#  'SepalLengthCm',
#  'SepalWidthCm',
#  'PetalLengthCm',
#  'PetalWidthCm',
#  'Species']

# %%
Iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
Iris_df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
Iris_df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
fig, axs = plt.subplots(5, figsize = (5,5))
plt1 = sns.boxplot(Iris_df['Id'], ax = axs[0])
plt2 = sns.boxplot(Iris_df['SepalLengthCm'], ax = axs[1])
plt3 = sns.boxplot(Iris_df['PetalLengthCm'], ax = axs[2])
plt3 = sns.boxplot(Iris_df['PetalWidthCm'], ax = axs[3])
plt4 = sns.boxplot(Iris_df['SepalWidthCm'], ax = axs[4])
plt.tight_layout()

# %%
x=pd.DataFrame(Iris_df,columns=["SepalLengthCm"]).values
y=Iris_df.Species.values.reshape(-1,1)

# %%
x
# Out:
# array([[5.1],
#        [4.9],
#        [4.7],
#        [4.6],
#        [5. ],
#        [5.4],
#        [4.6],
#        [5. ],
#        [4.4],
#        [4.9],
#        [5.4],
#        [4.8],
#        [4.8],
#        [4.3],
#        [5.8],
#        [5.7],
#        [5.4],
#        [5.1],
#        [5.7],
#        [5.1],
#        [5.4],
#        [5.1],
#        [4.6],
#        [5.1],
#        [4.8],
#        [5. ],
#        [5. ],
#        [5.2],
#        [5.2],
#        [4.7],
#        [4.8],
#        [5.4],
#        [5.2],
#        [5.5],
#        [4.9],
#        [5. ],
#        [5.5],
#        [4.9],
#        [4.4],
#        [5.1],
#        [5. ],
#        [4.5],
#        [4.4],
#        [5. ],
#        [5.1],
#        [4.8],
#        [5.1],
#        [4.6],
#        [5.3],
#        [5. ],
#        [7. ],
#        [6.4],
#        [6.9],
#        [5.5],
#        [6.5],
#        [5.7],
#        [6.3],
#        [4.9],
#        [6.6],
#        [5.2],
#        [5. ],
#        [5.9],
# ...

# %%
y
# Out:
# array([['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
# ...

# %%
sns.distplot(Iris_df['SepalWidthCm'])
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Density'>

# %%
iqr = Iris_df.SepalWidthCm.quantile(0.75) - Iris_df.SepalWidthCm.quantile(0.25)
print(iqr)
# Out:
# 0.5

# %%
lower_bridge = Iris_df["SepalWidthCm"].quantile(0.25) - (iqr*1.5)
upper_bridge = Iris_df["SepalWidthCm"].quantile(0.75) +(iqr*1.5)
print(lower_bridge)
print(upper_bridge)
# Out:
# 2.05
# 4.05

# %%
Data = Iris_df.copy()

# %%
Data.loc[Data['SepalWidthCm']>=4.0, 'SepalWidthCm']=4.0

# %%
sns.boxplot(Data["SepalWidthCm"]);

# %% [markdown]
# explanatory Data Analysis
# Univariate analysis
# output/target variable is iris flower

# %%
x=pd.DataFrame(Iris_df,columns=["SepalLengthCm","SepalWidthCm","PetalLengthCm","PetalWidthCm"]).values
y=Iris_df.Species.values.reshape(-1,1)

# %%
x
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
y
# Out:
# array([['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
#        ['Iris-setosa'],
# ...

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
import warnings

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.30,random_state=42)

# %%
k=7

clf=KNeighborsClassifier(k)

clf.fit(x_train,y_train)

y_pred=clf.predict(x_test)

# %%
metrics.accuracy_score(y_test,y_pred)*100
# Out:
# 100.0
